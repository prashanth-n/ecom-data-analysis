# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

customer_data_df = pd.read_csv("../data/raw/olist_customers_dataset.csv")
geolocation_data_df = pd.read_csv("../data/raw/olist_geolocation_dataset.csv")
order_items_df = pd.read_csv("../data/raw/olist_order_items_dataset.csv")
order_payments_df = pd.read_csv("../data/raw/olist_order_payments_dataset.csv")
order_reviews_df = pd.read_csv("../data/raw/olist_order_reviews_dataset.csv")
orders_df = pd.read_csv("../data/raw/olist_orders_dataset.csv")
products_df = pd.read_csv("../data/raw/olist_products_dataset.csv")
sellers_df = pd.read_csv("../data/raw/olist_sellers_dataset.csv")
product_category_name_translated_df = pd.read_csv("../data/raw/product_category_name_translation.csv")

prices = order_items_df['price']
plt.figure(figsize=(10,6))
plt.hist(prices, bins=50)
plt.title('Distribution of Order Item Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

orders_per_day = orders_df.groupby('order_approved_at').size()
orders_per_day.plot(kind='line', figsize=(12,12), title='Number of Orders per Day')
plt.xlabel('Date')
plt.ylabel('Number of Orders')
plt.show()

orders_df.head()
# def reviews_to_star(row):
#     if int(row.review_score) == 4:
#         return 4
#     elif int(row.review_score) == 3:
#         return 3
#     elif int(row.review_score) == 1:
#         return -1
    
# updtd = order_reviews_df.apply(reviews_to_star, axis="columns") 
# updtd
# order_payments_df.reset_index()
# order_payments_df.groupby(["payment_type"]).payment_value.agg([len, min, max])
# customer_data_df.groupby(["customer_city", "customer_state"])
# order_reviews_df.groupby("review_score").review_score.count()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...
